# %% [markdown]
# # EDA MID EXAM

# %% [markdown]
# ---------------------------

# %% [markdown]
# # SECTION A: 8 MARKS

# %% [markdown]
# --------------

# %% [markdown]
# ### 1. What is the difference between one hot encoding and label encoding? (8 MARKS)

# %%
ONE HOT ENCODING

One hot encoding is for dealing with categorical variables. It solely establishes the following characteristics established on
the volume of distinct values in the categorical features. Entire distinct values in the classification will be enlarged as an 
outline. One hot encoding takes a section which has categorical data, which has an existing label encoded and thn divides the 
section into numerous sections. The volumes are rebuilt by 1s and 0s, counting on which section has what value.
** The one hot encoder does not approve 1-D arrays. The input should always be a 2-D array.
** The data ratified to the encoder should not include strings.
        Vastly of the prevailing machine learning algorithms cannot be committed to categorical data. Rather, the categorical
data requires to be modified to numerical data. One hot encoding is one of the strategies utilized to conduct this conversion.
This technique is primarily utilized where deep learning methods are to correlate to sequential succession problems.

LABEL ENCODING

Label encoding cites the transmogrification of the labels into the numeric form to change it into a form that can be ready by 
the machine. Machine learning algorithms can thereafter determine in a correct way as to how these labels must be managed. It 
is crucial preprocessing measure during the integrated dataset in supervised learning.
        For example, we have a dataset that has comparison of a certain qaulity in a certain skill in the form of a superlative 
comparison betweeen siblings. The dataset is good, better, best. After applying a label encoder each quality will be a given a 
label 0,1,2 respectively. The label for good quality is 0, for the better the label is 1, for the best the label is 2.
        Label encoding in python can be implemented using sklearn library. sklearn furnishes a very effective method for
encoding the categories of categorical features into numeric values. Label encoder encodes labels with credit between 0 and n-1 
classes where n is the number of diverse labels. If a label reiterates it appoints the exact merit to as appointed before.

# %% [markdown]
# # SECTION B: 17 MARKS

# %% [markdown]
# -------------

# %% [markdown]
# ### Data Set Information:
#
# The time period of this dataset is from 2010 to 2018 when this notebook was written. It contains 36 columns that describe various properties of the volcano as well as data related to economic and human impact of the eruption. Properties that I feel are relevant and worthy of displaying on a marker pop up are "Year", "Name", "Country", "Latitude", "Longitude", "Type" although there are some tempting ones such as 'TOTALDAMAGEMILLIONSDOLLARS' and 'TOTALHOUSES_DESTROYED' that I chose to not include. This particular slice in time only contains 63 observations. The NOAA eruptions data is not real time nor is it updated fully as seen in the many null fields. I believe the data is entered as NOAA becomes aware of various situations related to that event.

# %% [markdown]
# * Year
#
# * TSU
#
# * EQ
#
# * Name
#
# * Elevation
#
# * Type
#
# * Status
#
# * Time
#
# * VEI
#
# * Agent
#
# * DEATHS
#
# * DEATHS_DESCRIPTION
#
# * MISSING
#
# * MISSING_DESCRIPTION
#
# * INJURIES
#
# * INJURIES_DESCRIPTION
#
# * DAMAGE_MILLIONS_DOLLARS
#
# * DAMAGE_DESCRIPTION
#
# * HOUSES_DESTROYED
#
# * HOUSES_DESTROYED_DESCRIPTION
#
# * TOTAL_DEATHS
#
# * TOTAL_DEATHS_DESCRIPTION
#
# * TOTAL_MISSING
#
# * TOTAL_MISSING_DESCRIPTION
#
# * TOTAL_INJURIES
#
# * TOTAL_INJURIES_DESCRIPTION
#
# * TOTAL_DAMAGE_MILLIONS_DOLLARS
#
# * TOTAL_DAMAGE_DESCRIPTION
#
# * TOTAL_HOUSES_DESTROYED
#
# * TOTAL_HOUSES_DESTROYED_DESCRIPTION
#
# * Latitude
#
# * Longitude
#
# * Country

# %%
# Kindly change the below cells from markdown to code and execute it

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

import csv

with open("data_set.csv","r")as file:
    
    reader=csv.reader(file)

df=pd.read_csv("data_set.csv")

df.head()
# Out:
#        Year  TSU   EQ                    Name  Elevation             Type  \
# 0  Jan 2010  NaN  NaN              Tungurahua       5023    Stratovolcano
# 1  Mar 2010  NaN  NaN        Eyjafjallajokull       1666    Stratovolcano
# 2  May 2010  NaN  NaN                  Pacaya       2552  Complex volcano
# 3  May 2010  TSU   EQ                 Sarigan        538    Stratovolcano
# 4  Aug 2010  NaN  NaN  Karangetang [Api Siau]       1784    Stratovolcano
#
#        Status Time  VEI Agent  ...  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0  Historical   D1  3.0   NaN  ...                        NaN             NaN
# 1  Historical   D1  2.0   NaN  ...                        NaN             NaN
# 2  Historical   D1  1.0     T  ...                        1.0             NaN
# 3    Holocene    U  NaN   NaN  ...                        NaN             NaN
# 4  Historical   D1  3.0   NaN  ...                        NaN             5.0
#
# ...

# %%
df.shape
# Out:
# (63, 33)

# %%
df.columns
# Out:
# Index(['Year', 'TSU', 'EQ', 'Name', 'Elevation', 'Type', 'Status', 'Time',
#        'VEI', 'Agent', 'DEATHS', 'DEATHS_DESCRIPTION', 'MISSING',
#        'MISSING_DESCRIPTION', 'INJURIES', 'INJURIES_DESCRIPTION',
#        'DAMAGE_MILLIONS_DOLLARS', 'DAMAGE_DESCRIPTION', 'HOUSES_DESTROYED',
#        'HOUSES_DESTROYED_DESCRIPTION', 'TOTAL_DEATHS',
#        'TOTAL_DEATHS_DESCRIPTION', 'TOTAL_MISSING',
#        'TOTAL_MISSING_DESCRIPTION', 'TOTAL_INJURIES',
#        'TOTAL_INJURIES_DESCRIPTION', 'TOTAL_DAMAGE_MILLIONS_DOLLARS',
#        'TOTAL_DAMAGE_DESCRIPTION', 'TOTAL_HOUSES_DESTROYED',
#        'TOTAL_HOUSES_DESTROYED_DESCRIPTION', 'Latitude', 'Longitude',
#        'Country'],
#       dtype='object')

# %%
df['Type'].value_counts()
# Out:
# Stratovolcano         45
# Shield volcano         9
# Caldera                3
# Complex volcano        3
# Lava dome              2
# Subglacial volcano     1
# Name: Type, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Indonesia           26
# United States        7
# Japan                5
# Papua New Guinea     3
# Ecuador              3
# Philippines          3
# Italy                2
# New Zealand          2
# Iceland              2
# Guatemala            2
# Vanuatu              2
# Chile                2
# Eritrea              1
# Russia               1
# Peru                 1
# Cape Verde           1
# Name: Country, dtype: int64

# %% [markdown]
# ### 2. Read the dataset and answer the below questions?
#
#
#  A. Considering `Type` as the dependent variable, display the different categories present under the variable 	`Type`? (4 MARK)
#
#  B. Find the top 3 countries which were worst affected by Volcanos based on the average damage in Dollars (5 MARKS)
#
#  C. Find the countries in which there were more number of missing people due to the volcano and also mention the type of volcano which caused it. (5 MARKS)"
#
#  D. Compare the 'Country' and 'Status' variable and provide inferences about the volcanic eruptions. (3 MARKS)

# %%
# A. 
ccol = df.select_dtypes(include = 'object')
print('Categorical columns are : ')
ccol
# Out:
# Categorical columns are :
#         Year  TSU   EQ                    Name                Type  \
# 0   Jan 2010  NaN  NaN              Tungurahua       Stratovolcano
# 1   Mar 2010  NaN  NaN        Eyjafjallajokull       Stratovolcano
# 2   May 2010  NaN  NaN                  Pacaya     Complex volcano
# 3   May 2010  TSU   EQ                 Sarigan       Stratovolcano
# 4   Aug 2010  NaN  NaN  Karangetang [Api Siau]       Stratovolcano
# 5   Aug 2010  NaN  NaN                Sinabung       Stratovolcano
# 6   Oct 2010  NaN  NaN                  Merapi       Stratovolcano
# 7   Nov 2010  NaN  NaN              Tungurahua       Stratovolcano
# 8   Dec 2010  NaN  NaN         Tengger Caldera       Stratovolcano
# 9   Jan 2011  NaN  NaN                  Merapi       Stratovolcano
# 10  Jan 2011  NaN  NaN               Kirishima      Shield volcano
# 11  Feb 2011  NaN  NaN                 Bulusan       Stratovolcano
# 12  Mar 2011  NaN  NaN  Karangetang [Api Siau]       Stratovolcano
# ...

# %%
# A.
ncol = df.select_dtypes(include = np.number)
print('Numerical columns are : ')
ncol
# Out:
# Numerical columns are :
#     Elevation  VEI  DEATHS  DEATHS_DESCRIPTION  MISSING  MISSING_DESCRIPTION  \
# 0        5023  3.0     NaN                 NaN      NaN                  NaN
# 1        1666  2.0     2.0                 1.0      NaN                  NaN
# 2        2552  1.0     1.0                 1.0      3.0                  1.0
# 3         538  NaN     NaN                 NaN      NaN                  NaN
# 4        1784  3.0     4.0                 1.0      NaN                  NaN
# 5        2460  NaN     2.0                 1.0      NaN                  NaN
# 6        2947  NaN   367.0                 3.0      NaN                  NaN
# 7        5023  3.0     NaN                 NaN      NaN                  NaN
# 8        2329  NaN     NaN                 NaN      NaN                  NaN
# 9        2947  NaN     1.0                 1.0      NaN                  NaN
# 10       1700  NaN     NaN                 NaN      NaN                  NaN
# ...

# %%
# B.
print('Top 3 countries which were worst affected by volancos on avg damage in dollars :\n')
df.groupby(['Country', 'Type']).mean()['TOTAL_DAMAGE_MILLIONS_DOLLARS'].sort_values(ascending = False).head(3)
# Out:
# Top 3 countries which were worst affected by volancos on avg damage in dollars :
# Country        Type
# Indonesia      Stratovolcano     350.00
# United States  Shield volcano     14.50
# Philippines    Stratovolcano       3.72
# Name: TOTAL_DAMAGE_MILLIONS_DOLLARS, dtype: float64

# %%
# C.
df.groupby(['Country', 'Type']).sum()['MISSING'].sort_values(ascending = False)
# Out:
# Country           Type
# Indonesia         Stratovolcano         44.0
# Guatemala         Complex volcano        3.0
# Vanuatu           Shield volcano         0.0
# Italy             Stratovolcano          0.0
# Chile             Stratovolcano          0.0
# Ecuador           Stratovolcano          0.0
# Eritrea           Stratovolcano          0.0
# Guatemala         Stratovolcano          0.0
# Iceland           Stratovolcano          0.0
#                   Subglacial volcano     0.0
# Indonesia         Complex volcano        0.0
# Italy             Caldera                0.0
# Japan             Caldera                0.0
# United States     Stratovolcano          0.0
# Japan             Complex volcano        0.0
#                   Shield volcano         0.0
#                   Stratovolcano          0.0
# New Zealand       Lava dome              0.0
# Papua New Guinea  Stratovolcano          0.0
# Peru              Stratovolcano          0.0
# ...

# %%
# D. 
plt.figure(figsize = (25,15))
sns.countplot(data = df, x = 'Country', hue = 'Status')
plt.show()

# %%
Inference about the volcanic eruptions from the above side by side bar graph "Indonesia" have the highest count of 
historical and "Holocene" status, where as "Tephrochronology" status can only be seen in United States.

# %%
df.Country
# Out:
# 0              Ecuador
# 1              Iceland
# 2            Guatemala
# 3        United States
# 4            Indonesia
# 5            Indonesia
# 6            Indonesia
# 7              Ecuador
# 8            Indonesia
# 9            Indonesia
# 10               Japan
# 11         Philippines
# 12           Indonesia
# 13             Ecuador
# 14               Chile
# 15             Eritrea
# 16             Iceland
# 17           Indonesia
# 18           Indonesia
# 19       United States
# 20       United States
# 21              Russia
# 22           Indonesia
# 23           Indonesia
# 24         Philippines
# 25           Indonesia
# 26                Peru
# 27               Japan
# 28           Indonesia
# 29         New Zealand
#             ...
# 33       United States
# 34          Cape Verde
# 35           Indonesia
# 36           Indonesia
# 37               Chile
# 38           Indonesia
# 39    Papua New Guinea
# 40           Indonesia
# 41         New Zealand
# ...

# %% [markdown]
# # SECTION C: 25 MARKS

# %% [markdown]
# ### 3. Using the above dataset, answer the below questions
#
#
#  a. Calculate the missing values percentage-wise (7 MARKS)
#
# **Sample output format:**
#
# Missing percentage in  TSU  is  96.83
#
# Missing percentage in  EQ  is  98.41
#
# ..
#
# ..
#
# ..
#
#
#
# Missing percentage in  TOTAL_HOUSES_DESTROYED  is  92.06
#
# Missing percentage in  TOTAL_HOUSES_DESTROYED_DESCRIPTION  is  77.78
#
#  b. Display the bar plot for the list of columns having null(NA) values more than 75% (7 MARKS)
#
#  c. Replace null values with 0 in the below variables (3 MARK)
#
#  'DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS',
#  'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING','TOTAL_INJURIES',
#  'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED'
#
#  d. After imputation, again check for the missing values in percentage(%), provide the inference (3 MARK)
#
#  e. Drop the columns which contain more than 50% of null values, name the new data frame as `data_new` (5 MARKS)"

# %% [markdown]
# ##### a. Calculate the missing values percentage-wise (7 MARKS)
#
# **Sample output format:**
#
# Missing percentage in  TSU  is  96.83
#
# Missing percentage in  EQ  is  98.41
#
# ..
#
# ..
#
# ..
#
#
#
# Missing percentage in  TOTAL_HOUSES_DESTROYED  is  92.06
#
# Missing percentage in  TOTAL_HOUSES_DESTROYED_DESCRIPTION  is  77.78

# %%
for i in df.columns:
    print('Missing percentage in {} is {}'.format(i, (df[i].isna().sum()/df.shape[0])* 100))
# Out:
# Missing percentage in Year is 0.0
# Missing percentage in TSU is 96.82539682539682
# Missing percentage in EQ is 98.4126984126984
# Missing percentage in Name is 0.0
# Missing percentage in Elevation is 0.0
# Missing percentage in Type is 0.0
# Missing percentage in Status is 0.0
# Missing percentage in Time is 0.0
# Missing percentage in VEI is 69.84126984126983
# Missing percentage in Agent is 63.49206349206349
# Missing percentage in DEATHS is 53.96825396825397
# Missing percentage in DEATHS_DESCRIPTION is 53.96825396825397
# Missing percentage in MISSING is 96.82539682539682
# Missing percentage in MISSING_DESCRIPTION is 96.82539682539682
# Missing percentage in INJURIES is 71.42857142857143
# Missing percentage in INJURIES_DESCRIPTION is 66.66666666666666
# Missing percentage in DAMAGE_MILLIONS_DOLLARS is 93.65079365079364
# Missing percentage in DAMAGE_DESCRIPTION is 34.92063492063492
# Missing percentage in HOUSES_DESTROYED is 88.88888888888889
# ...

# %% [markdown]
# ##### b. Display the bar plot for the list of columns having null(NA) values more than 75% (7 MARKS)

# %%
a = {}
for i in df.columns:
    if df[i].isna().sum()/df.shape[0]*100 >= 75:
        a[i] = df[i].isna().sum()/df.shape[0]*100
a
# Out:
# {'TSU': 96.82539682539682,
#  'EQ': 98.4126984126984,
#  'MISSING': 96.82539682539682,
#  'MISSING_DESCRIPTION': 96.82539682539682,
#  'DAMAGE_MILLIONS_DOLLARS': 93.65079365079364,
#  'HOUSES_DESTROYED': 88.88888888888889,
#  'TOTAL_MISSING': 96.82539682539682,
#  'TOTAL_MISSING_DESCRIPTION': 96.82539682539682,
#  'TOTAL_DAMAGE_MILLIONS_DOLLARS': 93.65079365079364,
#  'TOTAL_HOUSES_DESTROYED': 92.06349206349206,
#  'TOTAL_HOUSES_DESTROYED_DESCRIPTION': 77.77777777777779}

# %%
plt.figure(figsize = (25,8))
plt.bar(a.keys(), a.values())
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ##### c. Replace null values with 0 in the below variables (3 MARK)
#
# 'DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS', 'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING','TOTAL_INJURIES', 'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED'

# %%
df[['DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS', 'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING',
    'TOTAL_INJURIES', 'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED']] = df[['DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS', 'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING',
    'TOTAL_INJURIES', 'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED']].replace(np.nan, 0)

# %%
df
# Out:
#         Year  TSU   EQ                    Name  Elevation                Type  \
# 0   Jan 2010  NaN  NaN              Tungurahua       5023       Stratovolcano
# 1   Mar 2010  NaN  NaN        Eyjafjallajokull       1666       Stratovolcano
# 2   May 2010  NaN  NaN                  Pacaya       2552     Complex volcano
# 3   May 2010  TSU   EQ                 Sarigan        538       Stratovolcano
# 4   Aug 2010  NaN  NaN  Karangetang [Api Siau]       1784       Stratovolcano
# 5   Aug 2010  NaN  NaN                Sinabung       2460       Stratovolcano
# 6   Oct 2010  NaN  NaN                  Merapi       2947       Stratovolcano
# 7   Nov 2010  NaN  NaN              Tungurahua       5023       Stratovolcano
# 8   Dec 2010  NaN  NaN         Tengger Caldera       2329       Stratovolcano
# 9   Jan 2011  NaN  NaN                  Merapi       2947       Stratovolcano
# 10  Jan 2011  NaN  NaN               Kirishima       1700      Shield volcano
# ...

# %% [markdown]
# #### d. After imputation, again check for the missing values in percentage(%), provide the inference (3 MARK)

# %% [markdown]
# ##### e. Drop the columns which contain more than 50% of null values, name the new data frame as data_new (5 MARKS)"

# %%
c = 0
miss = []
for i in d.index:
    if d.values[x] > 50:
        y.append(i)
    x+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-f33c373c99ea> in <module>
#       2 y = []
#       3 for i in df.index:
# ----> 4     if df.values[x] > 50:
#       5         y.append(i)
#       6     x+=1
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# --------------------------
